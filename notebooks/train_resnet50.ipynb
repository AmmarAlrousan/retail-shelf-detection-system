# %%
import os
import cv2
import random
import shutil
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
from torchvision import transforms

# Input dataset directory
DATA_DIR = "/kaggle/input/label-cluster1"

# Output cleaned dataset directory
OUTPUT_DIR = "/kaggle/working/cleaned_dataset"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Preprocessing parameters
TARGET_SIZE = 224
BLUR_THRESHOLD = 60          # Below this → considered blurry
MIN_ASPECT_RATIO = 0.30      # Wrong crop filter
MAX_ASPECT_RATIO = 3.50

# %%
import os
import cv2
import random
import shutil
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from PIL import Image
from tqdm import tqdm
from torchvision import transforms

DATA_DIR = "/kaggle/input/label-cluster1"
OUTPUT_DIR = "/kaggle/working/cleaned_dataset"
os.makedirs(OUTPUT_DIR, exist_ok=True)

TARGET_SIZE = 224
BLUR_THRESHOLD = 60     # قيمة معيارية — أقل منها يعتبر Blurry
MIN_ASPECT = 0.3        # crop خاطئ
MAX_ASPECT = 3.5        # crop خاطئ

# %%
label_counts = {}
labels = [d for d in os.listdir(DATA_DIR) if os.path.isdir(os.path.join(DATA_DIR, d))]

for label in labels:
    img_files = [
        f for f in os.listdir(os.path.join(DATA_DIR, label))
        if f.lower().endswith(('.jpg','.jpeg','.png','.bmp'))
    ]
    label_counts[label] = len(img_files)

print("Number of labels:", len(label_counts))
for label, count in label_counts.items():
    print(f"{label}: {count}")
# Out:
# Number of labels: 91
# bottle_drink: 1973
# Hand_Soap_Pump_Bottles: 3277
# Dark_OTC_and_Hygiene_Mix: 6756
# Diaper_Packs: 2718
# Refill_and_Soft_Pouches: 2782
# shampo: 4789
# cream: 4107
# feet_care: 6521
# Men_Grooming_Dark: 4859
# Medicine_Soap_Detergent_Packs: 6567
# Powder_and_Supplement_Canisters: 4941
# Coffee_and_Breakfast_Packs: 5676
# hand_care: 3644
# Red_Box_Mix: 4574
# vitamine: 3335
# Manual_Dishwashing_Liquid: 2055
# Red_Orange_Grooming: 3034
# perfumes: 5119
# Beechams_Cold_Flu: 415
# Green_Pharmacy_and_Herbal: 5967
# shampo_hair: 4430
# tomato paste: 1029
# Mixed_Household_Grocery_Packs: 5475
# Feminine_Hygiene_Baskets: 5537
# Detergent_and_Cleaning: 2840
# Feminine_Hygiene_Dark: 5303
# Solid_Bar_Soap: 5902
# Scented_Candles_and_Diffusers: 2887
# CocaCola_Cans: 2868
# Bottles_Jars_Mix: 3778
# Pharmacy_Box: 5967
# Household_Pharmacy_Mix: 5292
# Soda_Cartons_Mixed: 3973
# Coffee_Canisters_Mix: 3883
# energy_drink: 4612
# Body_Care_General: 4353
# Large_Plastic_Soda_Bottles: 3390
# Body_Care_Mix: 4531
# Shampoo_Body_Wash_Mix: 2219
# Body_Lotions_and_Creams: 3932
# Dove_and_White_Body_Wash: 4274
# Body_Care_Light_Bottles: 3674
# Colorful_Household_Mix: 5255
# Food_Condiment_Jars: 3326
# Liquid_Soap_and_Body_Wash: 2562
# pepsi: 2786
# Household_Misc_Containers: 3255
# Folgers_Coffee_Canisters: 2025
# Hair_Dye_and_Cosmetics: 4315
# girl_game: 5514
# Green_Soda_Packs: 2932
# OTC_Medicine_General: 6902
# Coffee_Creamer_and_Spreads: 5670
# Soft_Hygiene_Packs: 4240
# OTC_Pain_and_Digestive_Relief: 7224
# Energy_Drink_Cans: 4946
# Tubs_and_Jars: 4178
# Dark_Personal_Care_Bottles: 3491
# Blue_Green_Boxes: 5352
# Deodorant_Sticks: 3555
# Lotion_and_Cream_Tubes: 3947
# Personal_Care_Mix: 5515
# White_OTC_Medicine_Boxes: 1010
# Foot_Care_and_Gadgets: 5129
# Dark_Soda_Bottles: 3397
# General_Pharmacy: 5257
# coffee_box: 4783
# Pantry_Condiment_Jars: 3448
# Beverage_Bottles: 3345
# creem: 4812
# Facial_Skincare_Tubes: 4035
# Soda_Bottles_Mixed: 3979
# Dish_and_Hand_Soap: 3087
# CocaCola_Cartons: 2753
# Green_Packs_Mix: 6146
# nova: 4244
# dove_shampo: 2769
# Aerosol_Deodorants: 4219
# cola_dark: 4684
# Personal_Care_Boxes: 5070
# Soda_Cartons_Colorful: 4064
# Mouthwash_and_Liquid_Soap: 3091
# Blue_Box_Mix: 4927
# Cylindrical_Tubs: 3589
# Liquid_Detergent_and_Bleach: 2574
# Feminine_Hygiene_Packs: 4855
# Oral_Care_Mix: 3643
# Bar_Soap_Packs: 4488
# Bagged_Coffee_Mix: 7724
# Colorful_Body_Wash_and_Deo: 3075
# CocaCola_DrPepper_Cartons: 3601

# %%
plt.figure(figsize=(18, 6))
plt.bar(label_counts.keys(), label_counts.values())
plt.xticks(rotation=90)
plt.title("Class Distribution")
plt.show()

# %%
STRONG_CLASSES = [cls for cls, cnt in label_counts.items() if cnt > 5000]
WEAK_CLASSES   = [cls for cls, cnt in label_counts.items() if cnt < 1000]

print("\nStrong Classes (>5000 images):")
print(STRONG_CLASSES)

print("\nWeak Classes (<1000 images):")
print(WEAK_CLASSES)
# Out:
# Strong Classes (>5000 images):
# ['Dark_OTC_and_Hygiene_Mix', 'feet_care', 'Medicine_Soap_Detergent_Packs', 'Coffee_and_Breakfast_Packs', 'perfumes', 'Green_Pharmacy_and_Herbal', 'Mixed_Household_Grocery_Packs', 'Feminine_Hygiene_Baskets', 'Feminine_Hygiene_Dark', 'Solid_Bar_Soap', 'Pharmacy_Box', 'Household_Pharmacy_Mix', 'Colorful_Household_Mix', 'girl_game', 'OTC_Medicine_General', 'Coffee_Creamer_and_Spreads', 'OTC_Pain_and_Digestive_Relief', 'Blue_Green_Boxes', 'Personal_Care_Mix', 'Foot_Care_and_Gadgets', 'General_Pharmacy', 'Green_Packs_Mix', 'Personal_Care_Boxes', 'Bagged_Coffee_Mix']
#
# Weak Classes (<1000 images):
# ['Beechams_Cold_Flu']

# %%
def show_cluster_samples(label, n=20):
    class_dir = os.path.join(DATA_DIR, label)
    images = [f for f in os.listdir(class_dir) if f.lower().endswith(('.jpg','.png','.jpeg'))]

    sample = random.sample(images, min(n, len(images)))

    plt.figure(figsize=(15, 8))
    for i, img_name in enumerate(sample):
        img_path = os.path.join(class_dir, img_name)
        img = Image.open(img_path)

        plt.subplot(4, 5, i+1)
        plt.imshow(img)
        plt.axis("off")

    plt.suptitle(f"Cluster Visual Review: {label}")
    plt.show()

# Example:
show_cluster_samples("Beechams_Cold_Flu")

# %%
#5) Data Cleaning
import os
import cv2
import shutil
from tqdm import tqdm

EXT = {'.jpg', '.jpeg', '.png'}  # faster lookup
RESIZE_FOR_BLUR_CHECK = (128, 128)  # downscale for Laplacian speedup

def fast_is_blurry(path, threshold=60):
    """Fast blur detection using grayscale + small resized image."""
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return True

    # Downscale image before Laplacian → MUCH faster
    small = cv2.resize(img, RESIZE_FOR_BLUR_CHECK, interpolation=cv2.INTER_AREA)
    fm = cv2.Laplacian(small, cv2.CV_64F).var()
    return fm < threshold


def fast_wrong_crop(path, min_ar=0.3, max_ar=3.5):
    """Fast aspect ratio check without heavy computations."""
    img = cv2.imread(path)
    if img is None:
        return True
    h, w = img.shape[:2]
    ar = h / w
    return ar < min_ar or ar > max_ar

# %%
for label in tqdm(labels, desc="Fast Cleaning Dataset"):
    src_dir = os.path.join(DATA_DIR, label)
    dst_dir = os.path.join(OUTPUT_DIR, label)
    os.makedirs(dst_dir, exist_ok=True)

    for fname in os.listdir(src_dir):
        if not any(fname.lower().endswith(ext) for ext in EXT):
            continue

        src_path = os.path.join(src_dir, fname)

        # Blur check
        if fast_is_blurry(src_path):
            continue

        # Wrong crop check
        if fast_wrong_crop(src_path):
            continue

        # Copy clean image
        shutil.copy2(src_path, os.path.join(dst_dir, fname))
# Out:
# Fast Cleaning Dataset: 100%|██████████| 91/91 [49:37<00:00, 32.72s/it]

# %%
clean_label_counts = {}
clean_labels = [d for d in os.listdir(OUTPUT_DIR) if os.path.isdir(os.path.join(OUTPUT_DIR, d))]

for label in clean_labels:
    img_files = [
        f for f in os.listdir(os.path.join(OUTPUT_DIR, label))
        if f.lower().endswith(('.jpg','.jpeg','.png'))
    ]
    clean_label_counts[label] = len(img_files)

print("Cleaned counts:")
for k, v in clean_label_counts.items():
    print(k, v)
# Out:
# Cleaned counts:
# Shampoo_Body_Wash_Mix 2099
# Large_Plastic_Soda_Bottles 3140
# Body_Care_Mix 3678
# shampo 4470
# Coffee_and_Breakfast_Packs 5653
# Personal_Care_Mix 5398
# CocaCola_Cartons 2595
# Bagged_Coffee_Mix 7705
# OTC_Medicine_General 6793
# CocaCola_DrPepper_Cartons 3476
# Hair_Dye_and_Cosmetics 4192
# Energy_Drink_Cans 4626
# Dove_and_White_Body_Wash 3976
# Dark_Soda_Bottles 3112
# Blue_Box_Mix 4443
# Red_Box_Mix 3912
# shampo_hair 4321
# Beechams_Cold_Flu 404
# Bar_Soap_Packs 4244
# Green_Soda_Packs 2851
# creem 4440
# Aerosol_Deodorants 3812
# Body_Care_General 2918
# feet_care 6454
# Tubs_and_Jars 3614
# Medicine_Soap_Detergent_Packs 6515
# Soda_Cartons_Mixed 3914
# dove_shampo 2657
# cream 4035
# Solid_Bar_Soap 5189
# White_OTC_Medicine_Boxes 971
# tomato paste 987
# Men_Grooming_Dark 4746
# Mixed_Household_Grocery_Packs 5424
# Household_Pharmacy_Mix 5221
# Body_Lotions_and_Creams 3786
# Mouthwash_and_Liquid_Soap 3012
# Powder_and_Supplement_Canisters 4773
# Cylindrical_Tubs 3241
# Beverage_Bottles 1462
# Red_Orange_Grooming 2911
# girl_game 5316
# vitamine 3184
# Bottles_Jars_Mix 3660
# Feminine_Hygiene_Dark 5099
# hand_care 3527
# Personal_Care_Boxes 4635
# cola_dark 3904
# Pharmacy_Box 5903
# Colorful_Household_Mix 5000
# Dark_Personal_Care_Bottles 3333
# Detergent_and_Cleaning 2776
# Deodorant_Sticks 3348
# Dish_and_Hand_Soap 3048
# Liquid_Detergent_and_Bleach 2540
# Oral_Care_Mix 3190
# Refill_and_Soft_Pouches 2703
# Lotion_and_Cream_Tubes 3859
# Pantry_Condiment_Jars 3212
# Colorful_Body_Wash_and_Deo 2948
# Soft_Hygiene_Packs 3964
# Hand_Soap_Pump_Bottles 3105
# Coffee_Canisters_Mix 3850
# Body_Care_Light_Bottles 3560
# Scented_Candles_and_Diffusers 2748
# Feminine_Hygiene_Baskets 5277
# Diaper_Packs 2612
# Green_Packs_Mix 4424
# coffee_box 4691
# bottle_drink 1474
# nova 4117
# pepsi 2623
# Food_Condiment_Jars 2650
# Blue_Green_Boxes 4937
# Folgers_Coffee_Canisters 1955
# Feminine_Hygiene_Packs 4721
# Manual_Dishwashing_Liquid 2021
# Facial_Skincare_Tubes 3921
# Soda_Cartons_Colorful 4012
# Green_Pharmacy_and_Herbal 5728
# OTC_Pain_and_Digestive_Relief 7101
# energy_drink 4143
# Liquid_Soap_and_Body_Wash 2409
# Soda_Bottles_Mixed 2125
# Dark_OTC_and_Hygiene_Mix 6627
# Coffee_Creamer_and_Spreads 5549
# perfumes 4796
# Foot_Care_and_Gadgets 5067
# CocaCola_Cans 2616
# General_Pharmacy 5018
# Household_Misc_Containers 3164

# %%
#6) Standardization (Resize + Normalization)
standard_transform = transforms.Compose([
    transforms.Resize((TARGET_SIZE, TARGET_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
# 7) Augmentation for Weak Classes

aug_transform = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.4, contrast=0.4),
    transforms.RandomPerspective(distortion_scale=0.5, p=0.4)
])

AUG_TARGET = 2000  # Minimum images per weak class

for label in WEAK_CLASSES:
    class_dir = os.path.join(OUTPUT_DIR, label)
    imgs = [f for f in os.listdir(class_dir) if f.lower().endswith('.jpg')]

    print(f"Augmenting class: {label}, current: {len(imgs)} → target: {AUG_TARGET}")

    while len(imgs) < AUG_TARGET:
        img_name = random.choice(imgs)
        img_path = os.path.join(class_dir, img_name)

        img = Image.open(img_path)
        aug = aug_transform(img)

        new_name = f"aug_{random.randint(0, 999999)}.jpg"
        aug.save(os.path.join(class_dir, new_name))

        imgs.append(new_name)
# Out:
# Augmenting class: Beechams_Cold_Flu, current: 2000 → target: 2000

# %%
#🚀 Train/Val/Test Split Code (70/15/15)
import os
import shutil
import random
from tqdm import tqdm

SOURCE_DIR = "/kaggle/working/cleaned_dataset"
SPLIT_DIR = "/kaggle/working/dataset_split"

train_ratio = 0.70
val_ratio = 0.15
test_ratio = 0.15

random.seed(42)

# Create split folders
for split in ["train", "val", "test"]:
    os.makedirs(os.path.join(SPLIT_DIR, split), exist_ok=True)

labels = [d for d in os.listdir(SOURCE_DIR) if os.path.isdir(os.path.join(SOURCE_DIR, d))]

for label in tqdm(labels, desc="Splitting Dataset"):
    class_dir = os.path.join(SOURCE_DIR, label)

    images = [f for f in os.listdir(class_dir) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
    random.shuffle(images)

    n = len(images)
    train_end = int(n * train_ratio)
    val_end = train_end + int(n * val_ratio)

    train_imgs = images[:train_end]
    val_imgs = images[train_end:val_end]
    test_imgs = images[val_end:]

    # Create class folders inside split directories
    os.makedirs(os.path.join(SPLIT_DIR, "train", label), exist_ok=True)
    os.makedirs(os.path.join(SPLIT_DIR, "val", label), exist_ok=True)
    os.makedirs(os.path.join(SPLIT_DIR, "test", label), exist_ok=True)

    # Copy images
    for img in train_imgs:
        shutil.copy2(os.path.join(class_dir, img), os.path.join(SPLIT_DIR, "train", label, img))

    for img in val_imgs:
        shutil.copy2(os.path.join(class_dir, img), os.path.join(SPLIT_DIR, "val", label, img))

    for img in test_imgs:
        shutil.copy2(os.path.join(class_dir, img), os.path.join(SPLIT_DIR, "test", label, img))

print("\nDataset split completed!")
# Out:
# Splitting Dataset: 100%|██████████| 91/91 [00:39<00:00,  2.29it/s]
# Dataset split completed!

# %%
import os
import random
from collections import Counter

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.models import resnet50, ResNet50_Weights

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# =====================
# Basic Config
# =====================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

DATA_ROOT = "/kaggle/working/dataset_split"
BATCH_SIZE = 64
NUM_WORKERS = 0
NUM_EPOCHS = 10
SEED = 42

random.seed(SEED)
torch.manual_seed(SEED)
if device.type == "cuda":
    torch.cuda.manual_seed_all(SEED)
# Out:
# Device: cuda

# %%
# ImageNet normalization
mean = [0.485, 0.456, 0.406]
std  = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

eval_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

train_dataset = datasets.ImageFolder(os.path.join(DATA_ROOT, "train"), transform=train_transform)
val_dataset   = datasets.ImageFolder(os.path.join(DATA_ROOT, "val"),   transform=eval_transform)
test_dataset  = datasets.ImageFolder(os.path.join(DATA_ROOT, "test"),  transform=eval_transform)

num_classes = len(train_dataset.classes)
print("Num classes:", num_classes)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)

# Class Weights
train_labels = [label for _, label in train_dataset.samples]
class_counts = Counter(train_labels)
num_samples = len(train_dataset)

class_weights = torch.tensor(
    [num_samples / (num_classes * class_counts[c]) for c in range(num_classes)],
    dtype=torch.float32
).to(device)

print("Class weights:", class_weights)
# Out:
# Num classes: 91
# Class weights: tensor([1.0232, 0.5062, 0.9192, 1.9500, 2.6686, 0.8778, 0.7901, 1.3369, 1.0955,
#         1.0606, 1.0302, 1.0656, 1.4910, 1.5033, 1.1221, 1.0130, 0.7029, 0.6899,
#         1.3233, 0.7800, 1.2037, 0.5886, 1.1702, 1.2534, 1.1652, 1.4050, 1.4934,
#         1.2799, 0.9809, 0.8431, 0.9949, 0.7392, 0.7649, 0.8263, 1.9956, 1.4725,
#         0.7699, 0.7773, 0.8818, 0.6810, 1.3684, 0.9305, 1.2563, 1.2330, 0.7471,
#         1.2420, 1.5354, 1.6192, 1.0107, 1.9307, 0.5987, 0.8218, 0.7192, 1.2951,
#         0.5741, 0.5493, 1.2226, 1.2144, 0.8415, 0.7226, 0.6607, 0.8171, 0.9971,
#         1.3402, 1.4429, 1.4196, 1.8584, 1.8359, 0.9722, 0.9967, 0.9841, 0.7516,
#         1.0795, 4.0206, 2.6479, 0.8315, 0.9993, 0.9667, 0.8784, 1.4685, 0.9414,
#         0.6044, 0.7337, 1.1061, 0.9476, 1.4869, 0.8132, 0.8725, 0.9028, 3.9565,
#         1.2253], device='cuda:0')

# %%
weights = ResNet50_Weights.IMAGENET1K_V2
model = resnet50(weights=weights)

# Replace classifier
model.fc = nn.Linear(model.fc.in_features, num_classes)

model = model.to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.3, patience=2
)

print("Model initialized:", next(model.parameters()).device)


class EarlyStopping:
    def __init__(self, patience=5):
        self.patience = patience
        self.counter = 0
        self.best_acc = 0
        self.early_stop = False

    def step(self, val_acc):
        if val_acc > self.best_acc:
            self.best_acc = val_acc
            self.counter = 0
        else:
            self.counter += 1
        if self.counter >= self.patience:
            self.early_stop = True


early_stopper = EarlyStopping()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 164MB/s]
# Model initialized: cuda:0

# %%
from tqdm.auto import tqdm
from torch.amp import autocast, GradScaler

scaler = GradScaler('cuda')

def train_one_epoch(model, loader, optimizer, criterion, device, scaler):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    pbar = tqdm(loader, desc="Training", leave=False)

    for images, labels in pbar:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        with autocast(device_type='cuda', dtype=torch.float16):
            outputs = model(images)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item() * images.size(0)
        correct += (outputs.argmax(1) == labels).sum().item()
        total += labels.size(0)

    return running_loss / total, correct / total


def eval_one_epoch(model, loader, criterion, device):
    model.eval()
    total, correct, running_loss = 0, 0, 0

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * images.size(0)
            correct += (outputs.argmax(1) == labels).sum().item()
            total += labels.size(0)

    return running_loss / total, correct / total

# %%
best_val_acc = 0
best_path = "/kaggle/working/resnet50_best.pth"

print("\n===== GPU CHECK =====")
print("GPUs:", torch.cuda.device_count())
print("Model device:", next(model.parameters()).device)

for epoch in range(NUM_EPOCHS):
    print(f"\n===== Epoch {epoch+1}/{NUM_EPOCHS} =====")

    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion, device, scaler)
    val_loss, val_acc = eval_one_epoch(model, val_loader, criterion, device)

    scheduler.step(val_loss)

    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc*100:.2f}%")
    print(f"Val Loss:   {val_loss:.4f} | Val Acc:   {val_acc*100:.2f}%")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), best_path)
        print(f"🔥 Best updated → {best_val_acc*100:.2f}%")

    early_stopper.step(val_acc)
    if early_stopper.early_stop:
        print("⛔ Early stopping triggered")
        break

print("\nTraining Done!")
print("Best Validation Accuracy:", best_val_acc * 100)
# Out:
# ===== GPU CHECK =====
# GPUs: 2
# Model device: cuda:0
#
# ===== Epoch 1/10 =====
# Training:   0%|          | 0/3882 [00:00<?, ?it/s]
# Train Loss: 1.6511 | Train Acc: 50.28%
# Val Loss:   1.4328 | Val Acc:   56.33%
# 🔥 Best updated → 56.33%
#
# ===== Epoch 2/10 =====
# Training:   0%|          | 0/3882 [00:00<?, ?it/s]
# Train Loss: 1.2614 | Train Acc: 59.34%
# Val Loss:   1.3013 | Val Acc:   59.42%
# 🔥 Best updated → 59.42%
#
# ===== Epoch 3/10 =====
# Training:   0%|          | 0/3882 [00:00<?, ?it/s]
# Train Loss: 1.1057 | Train Acc: 63.32%
# Val Loss:   1.2258 | Val Acc:   61.42%
# 🔥 Best updated → 61.42%
#
# ===== Epoch 4/10 =====
# Training:   0%|          | 0/3882 [00:00<?, ?it/s]
# Train Loss: 0.9704 | Train Acc: 66.97%
# Val Loss:   1.2060 | Val Acc:   61.99%
# 🔥 Best updated → 61.99%
#
# ===== Epoch 5/10 =====
# Training:   0%|          | 0/3882 [00:00<?, ?it/s]
# Train Loss: 0.8371 | Train Acc: 70.77%
# Val Loss:   1.2058 | Val Acc:   62.21%
# 🔥 Best updated → 62.21%
#
# ===== Epoch 6/10 =====
# Training:   0%|          | 0/3882 [00:00<?, ?it/s]
# Train Loss: 0.7008 | Train Acc: 74.82%
# Val Loss:   1.2100 | Val Acc:   63.00%
# 🔥 Best updated → 63.00%
#
# ===== Epoch 7/10 =====
# Training:   0%|          | 0/3882 [00:00<?, ?it/s]
# Train Loss: 0.5635 | Train Acc: 79.22%
# Val Loss:   1.2592 | Val Acc:   62.34%
#
# ===== Epoch 8/10 =====
# Training:   0%|          | 0/3882 [00:00<?, ?it/s]

# %%
import torch
import torch.nn as nn
from torchvision.models import resnet50, ResNet50_Weights

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

num_classes = len(train_dataset.classes)

# Create same model architecture used during training
model = resnet50(weights=ResNet50_Weights.IMAGENET1K_V2)

in_features = model.fc.in_features
model.fc = nn.Linear(in_features, num_classes)

best_model_path = "/kaggle/working/resnet50_best.pth"

# Load state dict
state_dict = torch.load(best_model_path, map_location=device)

# ----------- FIX: remove 'module.' prefix if exists -----------
new_state_dict = {}
for k, v in state_dict.items():
    if k.startswith("module."):
        new_state_dict[k[len("module."):]] = v   # remove 'module.'
    else:
        new_state_dict[k] = v

# Load corrected weights
model.load_state_dict(new_state_dict)

model = model.to(device)
model.eval()

print("🔥 Best model loaded successfully (with DP fix)!")
# Out:
# Using device: cuda
# 🔥 Best model loaded successfully (with DP fix)!

# %%
from tqdm import tqdm
import numpy as np

test_loss = 0
correct = 0
total = 0
criterion = nn.CrossEntropyLoss()

all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in tqdm(test_loader, desc="Testing"):
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        test_loss += loss.item() * images.size(0)

        preds = outputs.argmax(1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss = test_loss / total
test_acc = correct / total * 100

print(f"\n===== TEST RESULTS =====")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2f}%")
# Out:
# Testing: 100%|██████████| 834/834 [03:58<00:00,  3.50it/s]
# ===== TEST RESULTS =====
# Test Loss: 1.2097
# Test Accuracy: 63.00%

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        preds = outputs.argmax(1).cpu().numpy()
        labels = labels.cpu().numpy()

        all_preds.extend(preds)
        all_labels.extend(labels)

cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(14, 12))
sns.heatmap(cm, cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(14, 10))
sns.heatmap(cm, cmap="Blues", annot=False)
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report

print("\n===== Classification Report =====")
print(classification_report(all_labels, all_preds,
                            target_names=train_dataset.classes))
# Out:
# ===== Classification Report =====
#                                  precision    recall  f1-score   support
#
#              Aerosol_Deodorants       0.48      0.62      0.54       573
#               Bagged_Coffee_Mix       0.88      0.80      0.84      1157
#                  Bar_Soap_Packs       0.61      0.58      0.59       638
#               Beechams_Cold_Flu       0.90      0.98      0.94       300
#                Beverage_Bottles       0.65      0.70      0.67       220
#                    Blue_Box_Mix       0.50      0.65      0.56       667
#                Blue_Green_Boxes       0.53      0.66      0.59       742
#               Body_Care_General       0.61      0.40      0.49       439
#         Body_Care_Light_Bottles       0.61      0.53      0.57       534
#                   Body_Care_Mix       0.47      0.53      0.50       553
#         Body_Lotions_and_Creams       0.78      0.75      0.76       569
#                Bottles_Jars_Mix       0.73      0.81      0.77       549
#                   CocaCola_Cans       0.88      0.93      0.90       393
#                CocaCola_Cartons       0.92      0.79      0.85       390
#       CocaCola_DrPepper_Cartons       0.62      0.75      0.68       522
#            Coffee_Canisters_Mix       0.80      0.68      0.74       578
#      Coffee_Creamer_and_Spreads       0.83      0.90      0.87       833
#      Coffee_and_Breakfast_Packs       0.82      0.74      0.78       849
#      Colorful_Body_Wash_and_Deo       0.62      0.60      0.61       443
#          Colorful_Household_Mix       0.45      0.54      0.49       750
#                Cylindrical_Tubs       0.59      0.52      0.55       487
#        Dark_OTC_and_Hygiene_Mix       0.64      0.44      0.52       995
#      Dark_Personal_Care_Bottles       0.39      0.44      0.41       501
#               Dark_Soda_Bottles       0.70      0.55      0.62       468
#                Deodorant_Sticks       0.63      0.74      0.68       503
#          Detergent_and_Cleaning       0.47      0.44      0.46       417
#                    Diaper_Packs       0.90      0.96      0.92       393
#              Dish_and_Hand_Soap       0.55      0.67      0.61       458
#        Dove_and_White_Body_Wash       0.55      0.48      0.51       597
#               Energy_Drink_Cans       0.69      0.84      0.76       695
#           Facial_Skincare_Tubes       0.80      0.70      0.75       589
#        Feminine_Hygiene_Baskets       0.76      0.78      0.77       793
#           Feminine_Hygiene_Dark       0.52      0.59      0.55       766
#          Feminine_Hygiene_Packs       0.74      0.74      0.74       709
#        Folgers_Coffee_Canisters       0.80      0.88      0.84       294
#             Food_Condiment_Jars       0.79      0.69      0.73       399
#           Foot_Care_and_Gadgets       0.72      0.68      0.70       761
#                General_Pharmacy       0.67      0.61      0.64       754
#                 Green_Packs_Mix       0.72      0.71      0.72       665
#       Green_Pharmacy_and_Herbal       0.55      0.70      0.62       860
#                Green_Soda_Packs       0.59      0.87      0.70       429
#          Hair_Dye_and_Cosmetics       0.75      0.84      0.80       630
#          Hand_Soap_Pump_Bottles       0.50      0.60      0.54       467
#       Household_Misc_Containers       0.42      0.40      0.41       476
#          Household_Pharmacy_Mix       0.41      0.55      0.47       784
#      Large_Plastic_Soda_Bottles       0.79      0.72      0.75       471
#     Liquid_Detergent_and_Bleach       0.78      0.78      0.78       381
#       Liquid_Soap_and_Body_Wash       0.71      0.49      0.58       362
#          Lotion_and_Cream_Tubes       0.57      0.53      0.55       580
#       Manual_Dishwashing_Liquid       0.76      0.71      0.74       304
#   Medicine_Soap_Detergent_Packs       0.84      0.51      0.64       978
#               Men_Grooming_Dark       0.78      0.58      0.67       713
#   Mixed_Household_Grocery_Packs       0.51      0.52      0.51       815
#       Mouthwash_and_Liquid_Soap       0.50      0.56      0.53       453
#            OTC_Medicine_General       0.51      0.47      0.49      1020
#   OTC_Pain_and_Digestive_Relief       0.64      0.65      0.64      1066
#                   Oral_Care_Mix       0.36      0.45      0.40       479
#           Pantry_Condiment_Jars       0.69      0.51      0.59       483
#             Personal_Care_Boxes       0.59      0.49      0.54       696
#               Personal_Care_Mix       0.66      0.47      0.55       811
#                    Pharmacy_Box       0.63      0.57      0.60       886
# Powder_and_Supplement_Canisters       0.54      0.52      0.53       717
#                     Red_Box_Mix       0.68      0.83      0.75       588
#             Red_Orange_Grooming       0.51      0.57      0.54       438
#         Refill_and_Soft_Pouches       0.43      0.58      0.50       406
#   Scented_Candles_and_Diffusers       0.70      0.70      0.70       413
#           Shampoo_Body_Wash_Mix       0.56      0.66      0.61       316
#              Soda_Bottles_Mixed       0.62      0.55      0.58       320
#           Soda_Cartons_Colorful       0.70      0.54      0.61       603
#              Soda_Cartons_Mixed       0.64      0.67      0.66       588
#              Soft_Hygiene_Packs       0.49      0.65      0.56       596
#                  Solid_Bar_Soap       0.74      0.79      0.77       779
#                   Tubs_and_Jars       0.62      0.47      0.53       543
#        White_OTC_Medicine_Boxes       0.55      0.84      0.66       147
#                    bottle_drink       0.59      0.77      0.67       222
#                      coffee_box       0.56      0.68      0.61       705
#                       cola_dark       0.65      0.73      0.69       587
#                           cream       0.70      0.74      0.72       606
#                           creem       0.50      0.44      0.47       666
#                     dove_shampo       0.79      0.76      0.78       400
#                    energy_drink       0.68      0.63      0.65       622
#                       feet_care       0.56      0.27      0.37       969
#                       girl_game       0.75      0.68      0.71       798
#                       hand_care       0.71      0.61      0.66       530
#                            nova       0.49      0.44      0.46       619
#                           pepsi       0.72      0.87      0.79       394
#                        perfumes       0.49      0.47      0.48       720
#                          shampo       0.60      0.58      0.59       671
#                     shampo_hair       0.50      0.70      0.58       649
#                    tomato paste       0.73      0.89      0.81       149
#                        vitamine       0.65      0.58      0.61       479
#
#                        accuracy                           0.63     53327
#                       macro avg       0.64      0.64      0.64     53327
#                    weighted avg       0.64      0.63      0.63     53327

# %%
import numpy as np

class_correct = np.zeros(num_classes)
class_total = np.zeros(num_classes)

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        preds = outputs.argmax(1)

        for label, pred in zip(labels, preds):
            class_total[label] += 1
            if pred == label:
                class_correct[label] += 1

print("===== Per-Class Accuracy =====")
for i, cls_name in enumerate(train_dataset.classes):
    acc = 100 * class_correct[i] / class_total[i]
    print(f"{cls_name}: {acc:.2f}%")
# Out:
# ===== Per-Class Accuracy =====
# Aerosol_Deodorants: 61.78%
# Bagged_Coffee_Mix: 80.38%
# Bar_Soap_Packs: 57.68%
# Beechams_Cold_Flu: 97.67%
# Beverage_Bottles: 70.45%
# Blue_Box_Mix: 64.92%
# Blue_Green_Boxes: 66.31%
# Body_Care_General: 40.32%
# Body_Care_Light_Bottles: 53.00%
# Body_Care_Mix: 52.62%
# Body_Lotions_and_Creams: 74.52%
# Bottles_Jars_Mix: 81.06%
# CocaCola_Cans: 93.13%
# CocaCola_Cartons: 78.72%
# CocaCola_DrPepper_Cartons: 74.90%
# Coffee_Canisters_Mix: 68.34%
# Coffee_Creamer_and_Spreads: 90.28%
# Coffee_and_Breakfast_Packs: 73.85%
# Colorful_Body_Wash_and_Deo: 59.82%
# Colorful_Household_Mix: 53.87%
# Cylindrical_Tubs: 52.36%
# Dark_OTC_and_Hygiene_Mix: 44.32%
# Dark_Personal_Care_Bottles: 43.71%
# Dark_Soda_Bottles: 55.13%
# Deodorant_Sticks: 74.35%
# Detergent_and_Cleaning: 44.12%
# Diaper_Packs: 95.67%
# Dish_and_Hand_Soap: 67.25%
# Dove_and_White_Body_Wash: 48.07%
# Energy_Drink_Cans: 83.88%
# Facial_Skincare_Tubes: 70.46%
# Feminine_Hygiene_Baskets: 78.06%
# Feminine_Hygiene_Dark: 58.62%
# Feminine_Hygiene_Packs: 73.62%
# Folgers_Coffee_Canisters: 87.76%
# Food_Condiment_Jars: 68.67%
# Foot_Care_and_Gadgets: 68.46%
# General_Pharmacy: 60.61%
# Green_Packs_Mix: 70.83%
# Green_Pharmacy_and_Herbal: 70.12%
# Green_Soda_Packs: 87.18%
# Hair_Dye_and_Cosmetics: 84.44%
# Hand_Soap_Pump_Bottles: 59.53%
# Household_Misc_Containers: 40.13%
# Household_Pharmacy_Mix: 54.97%
# Large_Plastic_Soda_Bottles: 71.76%
# Liquid_Detergent_and_Bleach: 78.22%
# Liquid_Soap_and_Body_Wash: 48.90%
# Lotion_and_Cream_Tubes: 52.59%
# Manual_Dishwashing_Liquid: 71.38%
# Medicine_Soap_Detergent_Packs: 51.33%
# Men_Grooming_Dark: 58.35%
# Mixed_Household_Grocery_Packs: 52.27%
# Mouthwash_and_Liquid_Soap: 56.29%
# OTC_Medicine_General: 46.67%
# OTC_Pain_and_Digestive_Relief: 64.54%
# Oral_Care_Mix: 44.89%
# Pantry_Condiment_Jars: 51.14%
# Personal_Care_Boxes: 48.99%
# Personal_Care_Mix: 47.10%
# Pharmacy_Box: 57.22%
# Powder_and_Supplement_Canisters: 51.60%
# Red_Box_Mix: 82.99%
# Red_Orange_Grooming: 56.85%
# Refill_and_Soft_Pouches: 58.37%
# Scented_Candles_and_Diffusers: 70.46%
# Shampoo_Body_Wash_Mix: 65.82%
# Soda_Bottles_Mixed: 54.69%
# Soda_Cartons_Colorful: 54.06%
# Soda_Cartons_Mixed: 67.01%
# Soft_Hygiene_Packs: 65.27%
# Solid_Bar_Soap: 79.46%
# Tubs_and_Jars: 46.59%
# White_OTC_Medicine_Boxes: 83.67%
# bottle_drink: 77.48%
# coffee_box: 67.94%
# cola_dark: 73.25%
# cream: 73.60%
# creem: 44.14%
# dove_shampo: 76.00%
# energy_drink: 62.86%
# feet_care: 27.24%
# girl_game: 67.54%
# hand_care: 61.32%
# nova: 43.94%
# pepsi: 86.80%
# perfumes: 46.67%
# shampo: 58.27%
# shampo_hair: 70.11%
# tomato paste: 89.26%
# vitamine: 58.04%

# %%
from sklearn.metrics import classification_report

print("===== Classification Report =====")
print(classification_report(all_labels, all_preds, target_names=train_dataset.classes))
# Out:
# ===== Classification Report =====
#                                  precision    recall  f1-score   support
#
#              Aerosol_Deodorants       0.48      0.62      0.54       573
#               Bagged_Coffee_Mix       0.88      0.80      0.84      1157
#                  Bar_Soap_Packs       0.61      0.58      0.59       638
#               Beechams_Cold_Flu       0.90      0.98      0.94       300
#                Beverage_Bottles       0.65      0.70      0.67       220
#                    Blue_Box_Mix       0.50      0.65      0.56       667
#                Blue_Green_Boxes       0.53      0.66      0.59       742
#               Body_Care_General       0.61      0.40      0.49       439
#         Body_Care_Light_Bottles       0.61      0.53      0.57       534
#                   Body_Care_Mix       0.47      0.53      0.50       553
#         Body_Lotions_and_Creams       0.78      0.75      0.76       569
#                Bottles_Jars_Mix       0.73      0.81      0.77       549
#                   CocaCola_Cans       0.88      0.93      0.90       393
#                CocaCola_Cartons       0.92      0.79      0.85       390
#       CocaCola_DrPepper_Cartons       0.62      0.75      0.68       522
#            Coffee_Canisters_Mix       0.80      0.68      0.74       578
#      Coffee_Creamer_and_Spreads       0.83      0.90      0.87       833
#      Coffee_and_Breakfast_Packs       0.82      0.74      0.78       849
#      Colorful_Body_Wash_and_Deo       0.62      0.60      0.61       443
#          Colorful_Household_Mix       0.45      0.54      0.49       750
#                Cylindrical_Tubs       0.59      0.52      0.55       487
#        Dark_OTC_and_Hygiene_Mix       0.64      0.44      0.52       995
#      Dark_Personal_Care_Bottles       0.39      0.44      0.41       501
#               Dark_Soda_Bottles       0.70      0.55      0.62       468
#                Deodorant_Sticks       0.63      0.74      0.68       503
#          Detergent_and_Cleaning       0.47      0.44      0.46       417
#                    Diaper_Packs       0.90      0.96      0.92       393
#              Dish_and_Hand_Soap       0.55      0.67      0.61       458
#        Dove_and_White_Body_Wash       0.55      0.48      0.51       597
#               Energy_Drink_Cans       0.69      0.84      0.76       695
#           Facial_Skincare_Tubes       0.80      0.70      0.75       589
#        Feminine_Hygiene_Baskets       0.76      0.78      0.77       793
#           Feminine_Hygiene_Dark       0.52      0.59      0.55       766
#          Feminine_Hygiene_Packs       0.74      0.74      0.74       709
#        Folgers_Coffee_Canisters       0.80      0.88      0.84       294
#             Food_Condiment_Jars       0.79      0.69      0.73       399
#           Foot_Care_and_Gadgets       0.72      0.68      0.70       761
#                General_Pharmacy       0.67      0.61      0.64       754
#                 Green_Packs_Mix       0.72      0.71      0.72       665
#       Green_Pharmacy_and_Herbal       0.55      0.70      0.62       860
#                Green_Soda_Packs       0.59      0.87      0.70       429
#          Hair_Dye_and_Cosmetics       0.75      0.84      0.80       630
#          Hand_Soap_Pump_Bottles       0.50      0.60      0.54       467
#       Household_Misc_Containers       0.42      0.40      0.41       476
#          Household_Pharmacy_Mix       0.41      0.55      0.47       784
#      Large_Plastic_Soda_Bottles       0.79      0.72      0.75       471
#     Liquid_Detergent_and_Bleach       0.78      0.78      0.78       381
#       Liquid_Soap_and_Body_Wash       0.71      0.49      0.58       362
#          Lotion_and_Cream_Tubes       0.57      0.53      0.55       580
#       Manual_Dishwashing_Liquid       0.76      0.71      0.74       304
#   Medicine_Soap_Detergent_Packs       0.84      0.51      0.64       978
#               Men_Grooming_Dark       0.78      0.58      0.67       713
#   Mixed_Household_Grocery_Packs       0.51      0.52      0.51       815
#       Mouthwash_and_Liquid_Soap       0.50      0.56      0.53       453
#            OTC_Medicine_General       0.51      0.47      0.49      1020
#   OTC_Pain_and_Digestive_Relief       0.64      0.65      0.64      1066
#                   Oral_Care_Mix       0.36      0.45      0.40       479
#           Pantry_Condiment_Jars       0.69      0.51      0.59       483
#             Personal_Care_Boxes       0.59      0.49      0.54       696
#               Personal_Care_Mix       0.66      0.47      0.55       811
#                    Pharmacy_Box       0.63      0.57      0.60       886
# Powder_and_Supplement_Canisters       0.54      0.52      0.53       717
#                     Red_Box_Mix       0.68      0.83      0.75       588
#             Red_Orange_Grooming       0.51      0.57      0.54       438
#         Refill_and_Soft_Pouches       0.43      0.58      0.50       406
#   Scented_Candles_and_Diffusers       0.70      0.70      0.70       413
#           Shampoo_Body_Wash_Mix       0.56      0.66      0.61       316
#              Soda_Bottles_Mixed       0.62      0.55      0.58       320
#           Soda_Cartons_Colorful       0.70      0.54      0.61       603
#              Soda_Cartons_Mixed       0.64      0.67      0.66       588
#              Soft_Hygiene_Packs       0.49      0.65      0.56       596
#                  Solid_Bar_Soap       0.74      0.79      0.77       779
#                   Tubs_and_Jars       0.62      0.47      0.53       543
#        White_OTC_Medicine_Boxes       0.55      0.84      0.66       147
#                    bottle_drink       0.59      0.77      0.67       222
#                      coffee_box       0.56      0.68      0.61       705
#                       cola_dark       0.65      0.73      0.69       587
#                           cream       0.70      0.74      0.72       606
#                           creem       0.50      0.44      0.47       666
#                     dove_shampo       0.79      0.76      0.78       400
#                    energy_drink       0.68      0.63      0.65       622
#                       feet_care       0.56      0.27      0.37       969
#                       girl_game       0.75      0.68      0.71       798
#                       hand_care       0.71      0.61      0.66       530
#                            nova       0.49      0.44      0.46       619
#                           pepsi       0.72      0.87      0.79       394
#                        perfumes       0.49      0.47      0.48       720
#                          shampo       0.60      0.58      0.59       671
#                     shampo_hair       0.50      0.70      0.58       649
#                    tomato paste       0.73      0.89      0.81       149
#                        vitamine       0.65      0.58      0.61       479
#
#                        accuracy                           0.63     53327
#                       macro avg       0.64      0.64      0.64     53327
#                    weighted avg       0.64      0.63      0.63     53327

# %%
top5_correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        _, top5 = outputs.topk(5, dim=1)

        for i in range(labels.size(0)):
            if labels[i] in top5[i]:
                top5_correct += 1

        total += labels.size(0)

top5_acc = 100 * top5_correct / total
print(f"🥇 Top-5 Accuracy: {top5_acc:.2f}%")
# Out:
# 🥇 Top-5 Accuracy: 93.36%

# %%
import random
import matplotlib.pyplot as plt

model.eval()

for _ in range(5):  # Show 5 random examples
    idx = random.randint(0, len(test_dataset)-1)
    img, true_label = test_dataset[idx]
    img_tensor = img.unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(img_tensor)
        pred = output.argmax(1).item()

    plt.imshow(test_dataset[idx][0].permute(1, 2, 0) * torch.tensor(std) + torch.tensor(mean))
    plt.title(f"True: {test_dataset.classes[true_label]}\nPred: {test_dataset.classes[pred]}")
    plt.axis("off")
    plt.show()

# %%
import pandas as pd

records = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        preds = outputs.argmax(1).cpu().numpy()
        labels = labels.cpu().numpy()

        for t, p in zip(labels, preds):
            records.append({
                "true_label": train_dataset.classes[t],
                "predicted_label": train_dataset.classes[p]
            })

df = pd.DataFrame(records)
df.to_csv("/kaggle/working/test_predictions.csv", index=False)

print("📁 Saved test predictions to test_predictions.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2851/2889237467.py in <cell line: 0>()
#       4
#       5 with torch.no_grad():
# ----> 6     for images, labels in test_loader:
#       7         images = images.to(device)
#       8         outputs = model(images)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     762     def _next_data(self):
#     763         index = self._next_index()  # may raise StopIteration
# --> 764         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765         if self._pin_memory:
#     766             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     245         sample = self.loader(path)
#     246         if self.transform is not None:
# --> 247             sample = self.transform(sample)
#     248         if self.target_transform is not None:
#     249             target = self.target_transform(target)
#
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#     135             Tensor: Converted image.
#     136         """
# --> 137         return F.to_tensor(pic)
#     138
#     139     def __repr__(self) -> str:
#
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional.py in to_tensor(pic)
#     166     # handle PIL Image
#     167     mode_to_nptype = {"I": np.int32, "I;16" if sys.byteorder == "little" else "I;16B": np.int16, "F": np.float32}
# --> 168     img = torch.from_numpy(np.array(pic, mode_to_nptype.get(pic.mode, np.uint8), copy=True))
#     169
#     170     if pic.mode == "1":
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in __array_interface__(self)
#     733             new["data"] = self.tobytes("raw", "L")
#     734         else:
# --> 735             new["data"] = self.tobytes()
#     736         new["shape"], new["typestr"] = _conv_type_shape(self)
#     737         return new
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in tobytes(self, encoder_name, *args)
#     809         output = []
#     810         while True:
# --> 811             bytes_consumed, errcode, data = e.encode(bufsize)
#     812             output.append(data)
#     813             if errcode:
#
# KeyboardInterrupt:

# %%
    import shutil

zip_path = "/kaggle/working/cleaned_dataset.zip"
folder_path = "/kaggle/working/cleaned_dataset"

shutil.make_archive("/kaggle/working/cleaned_dataset", "zip", folder_path)

print("Done — ZIP created:", zip_path)
# Out:
# Done — ZIP created: /kaggle/working/cleaned_dataset.zip

# %%
from IPython.display import FileLink

FileLink("/kaggle/working/cleaned_dataset.zip")
